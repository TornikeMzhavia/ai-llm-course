# %%
from openai import OpenAI  # must install openai package
from pathlib import Path
import os

from dotenv import load_dotenv

# Load .env from project root (parent directory)
project_root = Path(os.path.abspath('')).resolve().parent.parent
load_dotenv(project_root / ".env")

client = OpenAI()

model = "gpt-4o-mini"

# %% [markdown]
# # Few-Shot Learning

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a translator."},
        {
            "role": "user",
            "content": """ Translate these sentences: 
            'Hello' -> 'Hola', 
            'Goodbye' -> 'Adiós'. 
            '.
             Now translate: 'Thank you'.""",
        },
    ],
)
print(completion.choices[0].message.content)
# Out:
# 'Thank you' -> 'Gracias'.

# %% [markdown]
# # Zero-Shot Prompting

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"},
    ],
)

print(completion.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# # Chain of Thought

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a math tutor."},
        {
            "role": "user",
            "content": "Solve this math problem step by step: If John has 5 apples and gives 2 to Mary, how many does he have left?",
        },
    ],
)
print(completion.choices[0].message.content)
# Out:
# Let's solve the problem step by step:
#
# 1. **Determine the initial number of apples John has**:
#    - John starts with 5 apples.
#
# 2. **Determine how many apples he gives to Mary**:
#    - John gives 2 apples to Mary.
#
# 3. **Calculate the number of apples John has left**:
#    - To find out how many apples John has left, we subtract the number of apples he gave away from the initial amount:
#    \[
#    5 \, (\text{initial apples}) - 2 \, (\text{apples given to Mary}) = 3 \, (\text{apples left})
#    \]
#
# 4. **Conclusion**:
#    - After giving 2 apples to Mary, John has 3 apples left.
#
# Thus, the answer is that John has **3 apples** left.

# %% [markdown]
# # Instructional Prompts

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {
            "role": "system",
            "content": "You a knowledgeable personal trainer and writer.",
        },
        {
            "role": "user",
            "content": "Write a 300-word summary of the benefits of exercise, using bullet points.",
        },
    ],
)
print(completion.choices[0].message.content)
# Out:
# ### Benefits of Exercise
#
# - **Physical Health**:
#   - Improves cardiovascular fitness, enhancing heart and lung function.
#   - Aids in weight management by burning calories and building muscle.
#   - Strengthens bones and muscles, reducing the risk of osteoporosis and injury.
#   - Boosts the immune system, helping to prevent various illnesses.
#
# - **Mental Health**:
#   - Reduces symptoms of anxiety and depression by releasing endorphins, the body’s natural mood lifters.
#   - Enhances cognitive function and memory, contributing to improved focus and concentration.
#   - Aids in stress management, providing a productive outlet for built-up tension.
#
# - **Sleep Quality**:
#   - Promotes better sleep patterns, facilitating longer and deeper sleep cycles.
#   - Helps to regulate circadian rhythms, making it easier to fall asleep and wake up refreshed.
#
# - **Social Benefits**:
#   - Provides opportunities for social interaction and camaraderie through group classes, sports, or gym activities.
#   - Enhances teamwork skills and builds a sense of community among participants.
#
# - **Increased Energy Levels**:
#   - Regular physical activity boosts energy by improving muscle strength and endurance.
#   - Enhances overall productivity by increasing alertness and reducing fatigue during daily activities.
#
# - **Longevity**:
#   - Regular exercise is associated with a longer lifespan and reduced risk of chronic diseases, such as diabetes and heart disease.
#
# - **Improved Self-Esteem and Confidence**:
#   - Achieving fitness goals fosters a sense of accomplishment and boosts self-esteem.
#   - Regular physical activity can enhance physical appearance and body image.
#
# Incorporating exercise into daily life can lead to comprehensive benefits, positively impacting physical, mental, and social well-being.

# %% [markdown]
# # Role-Playing Prompts

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a character in a fantasy novel."},
        {
            "role": "user",
            "content": "Describe the setting of the story.",
        },
    ],
)
print(completion.choices[0].message.content)
# Out:
# The story unfolds in the mystical realm of Eldoria, a land of vibrant landscapes and ancient magic. The skies shimmer in hues of lavender and gold, illuminated by two suns that grace the horizon during the day. Cumulonimbus clouds float like cotton candy, casting playful shadows over the lush emerald valleys below.
#
# At the center of Eldoria lies the Enchanted Forest, a sprawling woodland filled with towering trees whose trunks are encircled by luminescent vines. The air within the forest is thick with enchantment, where whispers of long-forgotten spells echo softly through the leaves. Creatures of all shapes and sizes inhabit this magical grove, from graceful faeries flitting between blossoms to elusive stag-like beings known as the Elderglow, their antlers sparkling like starlit skies.
#
# To the north, the Frostpeak Mountains rise sharply, their jagged cliffs blanketed in eternal snow. A radiant waterfall cascades down from the highest peak, its waters revered for their healing properties and said to hold the memories of the land. Nearby, the village of Brighthaven clings to the mountainside, its stone cottages adorned with flowering vines and bustling with the warmth of camaraderie. Here, villagers trade stories and craftsmanship, their laughter mingling with the songs of traveling bards.
#
# In stark contrast is the Shadowmarsh, a mysterious swampland that borders the southern edge of Eldoria. Its murky waters and twisted cypress trees create a haunting beauty, but many avoid it, whispering of the dark spirits said to haunt its depths. The marsh holds secrets both perilous and profound, guarding enchantments that have been lost to the ages.
#
# As the seasons shift, Eldoria transforms dramatically; spring paints the landscape with blossoms, summer brings vibrant festivals, autumn cloaks the realm in fiery hues, and winter wraps it all in a serene blanket of snow. Each season carries its own magic and challenges, drawing adventurers and scholars alike to uncover the legends that ebb like the tides of the sea.
#
# Eldoria is a land at the crossroads of destiny, where paths intertwine, heroes are forged, and the age-old battle between light and shadow plays out against an ever-changing tapestry of wonder and peril.

# %% [markdown]
# # Open-Ended Prompt

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a philosopher."},
        {
            "role": "user",
            "content": "What is the meaning of life?",
        },
    ],
)
print(completion.choices[0].message.content)
# Out:
# The question of the meaning of life has been a central topic in philosophy, religion, and personal reflection for centuries, and there are many perspectives on it. Here are a few ways to approach the meaning of life:
#
# 1. **Existential Perspective**: Existentialists like Jean-Paul Sartre and Albert Camus suggest that life has no inherent meaning, and it's up to each individual to create their own meaning through choices, actions, and personal values.
#
# 2. **Religious Perspective**: Many religions provide specific meanings and purposes for life. For example, Christianity often sees life as a journey towards knowing God and fulfilling His will, while Buddhism might focus on the cessation of suffering and the attainment of enlightenment.
#
# 3. **Humanistic Perspective**: Humanists emphasize human experience and rational thinking, suggesting that meaning can be derived from relationships, personal fulfillment, and contributing to the betterment of society.
#
# 4. **Utilitarian Perspective**: From a utilitarian viewpoint, the meaning of life could be understood in terms of maximizing happiness and minimizing suffering for the greatest number of people.
#
# 5. **Biological Perspective**: From a scientific standpoint, the meaning of life might be viewed in terms of survival, reproduction, and the continuation of the species.
#
# Ultimately, the meaning of life may be inherently subjective, varying widely based on individual beliefs, cultural context, and life experiences. Each person may find their own answer through exploration, reflection, and engagement with the world around them.

# %% [markdown]
# # Temperature and Top-P Sampling

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a creative writer."},
        {"role": "user", "content": "Write a creative tagline for a coffee shop."},
    ],
    #temperature=0.9,  # controls the randomness of the output
    #top_p=0.9,  # controls the diversity of the output
)
print(completion.choices[0].message.content)
# Out:
# "Awaken Your Senses: Sip, Savor, Smile."

# %% [markdown]
# # Combining Techniques (with Streaming)

# %%
completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a travel blogger."},
        {
            "role": "user",
            "content": "Write a 500-word blog post about your recent trip to Paris. Make sure to give a step-by-step itinerary of your trip.",
        },
    ],
    temperature=0.9,
    stream=True,
    # top_p=0.9,
)
# print(completion.choices[0].message.content)
for chunk in completion:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content or "", end="")
# Out:
# **Exploring the City of Light: A Memorable 4-Day Itinerary in Paris**
#
# Ah, Paris! The city of love, art, and exquisite cuisine. After a long wait, I finally found myself wandering the charming streets of this iconic city. Here’s a detailed step-by-step itinerary for my recent four-day trip to Paris that captures the essence of this enchanting destination.
#
# **Day 1: Arrival and Montmartre Exploration**
#
# *Morning:*
# I landed at Charles de Gaulle Airport and took the RER B train straight to central Paris. The fresh air filled my lungs as I stepped out at Gare du Nord. After checking in at my cozy hotel in Montmartre, I was eager to shed the travel fatigue.
#
# *Afternoon:*
# My first stop was the enchanting Sacré-Cœur Basilica. The striking white dome against the bright blue sky was breathtaking. I climbed the dome for panoramic views of the city—definitely worth the 300+ steps!
#
# Post-visit, I strolled through the cobbled streets of Montmartre, stopping by the iconic Café des Deux Moulins (thanks, Amélie!) for a light lunch of croque-monsieur and a delightful café au lait.
#
# *Evening:*
# As the sun began to set, I visited the Place du Tertre, where local artists showcase their work. Watching the sketch artists was a delightful experience. I concluded my day with dinner at La Mère Catherine, indulging in coq au vin paired with a robust French red wine.
#
# ---
#
# **Day 2: Museums and Historic Landmarks**
#
# *Morning:*
# After a hearty breakfast at my hotel, I made my way to the Louvre Museum. I spent hours marveling at timeless masterpieces, including the Mona Lisa and the Venus de Milo. Pro tip: pre-book your tickets to skip the long lines!
#
# *Afternoon:*
# Next, I headed to the nearby Palais Royal, where I strolled through the serene gardens. For lunch, I enjoyed a delightful salade niçoise at a quaint bistro tucked away in Le Marais district.
#
# *Evening:*
# I dedicated my evening to the stunning Notre-Dame Cathedral. Despite the ongoing restoration efforts, the grandeur was undeniable. I then took a leisurely walk along the Seine, soaking in the views of the city lights. For dinner, I treated myself to a meal at a riverside brasserie, savoring escargots as my starter and a classic beef Bourguignon as my main.
#
# ---
#
# **Day 3: A Day in Versailles**
#
# *Morning:*
# An early train ride took me to the opulent Palace of Versailles. With a pre-booked guided tour, I was able to bypass the lines. The Hall of Mirrors is an absolute must-see, reflecting the grandeur of French royalty.
#
# *Afternoon:*
# After touring the palace, I explored the expansive gardens. The fountains dancing to classical music was a magical experience. I indulged in a picnic lunch with fresh baguettes, cheese, and strawberries in the gardens—pure bliss!
#
# *Evening:*
# I returned to Paris and decided to dine at Le Relais de l’Entrecôte, known for their secret sauce steak. I ended the night with a Seine River cruise, offering scenic views of Paris illuminated at night.
#
# ---
#
# **Day 4: Culture and Shopping**
#
# *Morning:*
# I kicked off my final day in the Latin Quarter, visiting the Panthéon. Afterward, I strolled along Rue Mouffetard, where I picked up some gourmet treats.
#
# *Afternoon:*
# A visit to the Musée d'Orsay followed, admiring the Impressionist masterpieces. I decided to indulge in shopping at the iconic Galeries Lafayette. The rooftop terrace offered breathtaking views of the Eiffel Tower.
#
# *Evening:*
# I wrapped up my Parisian adventure with a delightful dinner at a cozy wine bar in Saint-Germain-des-Prés. My heart was full as I reflected on a journey filled with memories.
#
# Paris, with its rich history and vibrant atmosphere, is a place that truly captures the soul. Until next time, I say au revoir!
